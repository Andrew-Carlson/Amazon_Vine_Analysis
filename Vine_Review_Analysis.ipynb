# %%
# import dependencies
import pandas as pd

# %%
# read in csv file containing vine table
df = pd.read_csv("./data/vine_table.csv", sep = ",")
df.head(10)
# Out:
#         review_id  star_rating  helpful_votes  total_votes vine  \
# 0   RMDCHWD0Y5OZ9          3.0            0.0          1.0    N
# 1   RZSL0BALIYUNU          5.0            0.0          0.0    N
# 2   RIZR67JKUDBI0          3.0            0.0          1.0    N
# 3  R27HL570VNL85F          5.0            0.0          0.0    N
# 4  R34EBU9QDWJ1GD          5.0            0.0          0.0    N
# 5  R1WCUI4Z1SIQEO          5.0            0.0          0.0    N
# 6   RL5LNO26GAVJ1          2.0            3.0          4.0    N
# 7  R3GYQ5W8JHP8SB          5.0            0.0          0.0    N
# 8  R30SHYQXGG5EYC          5.0            0.0          0.0    N
# 9  R14YLXA56NP51I          5.0            1.0          1.0    N
#
#   verified_purchase
# 0                 N
# 1                 Y
# 2                 Y
# 3                 Y
# 4                 Y
# 5                 N
# 6                 Y
# 7                 Y
# 8                 Y
# 9                 N
